# %% [markdown]
# # Middleware
#
# Middleware provides a way to more tightly control what happens inside the agent. Middleware is useful for the following:
# - Tracking agent behavior with logging, analytics and debugging.
# - Transforming prompts, tool selection, and output formatting.
# - Adding retries, fallbacks and early termination logic.
# - Applying rate limits, guardrails, and PII detection.

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## Summarization Middleware
#
# Automatically summarize conversation history when approaching token limits, preserving recent messages while compressing older context. Summarization is useful for the following:
# - Long-running conversations that exceed the context window
# - Multi-turn dialogues with extensive history
# - Applications where preserving full conversational context matters

# %% [markdown]
# #### Based on Number of the Messages/Conversations

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.messages import HumanMessage, SystemMessage

### Message based summarizations
agent=create_agent(
    model='gpt-4o-mini',
    checkpointer=MemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model='gpt-4o-mini',
            trigger=("messages", 10),
            keep=("messages", 4)
        )
    ]
)

# %%
## Run with a thread ID
config={"configurable": {"thread_id":"test-1"}}

# %%
from langchain_core.messages import HumanMessage
# Alternative test data
questions = [
    "what is 2+2?",
    "what is 10*5?",
    "what is 23*10?",
    "what is 18+11?",
    "what is 22/7?",
    "what is 100/4?"
]

for q in questions:
    response=agent.invoke({"messages":[HumanMessage(content=q)]},config)
    print(f"Messages: {response}")
    print(f"Len of Messages: {len(response['messages'])}")
# Out:
# Messages: {'messages': [HumanMessage(content='what is 2+2?', additional_kwargs={}, response_metadata={}, id='3bdd9ba8-801b-4cf0-b18c-88fa0dce456e'), AIMessage(content='2 + 2 equals 4.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 14, 'total_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UKX7tVbXHFxtVoyG1EdqbEOTJnP', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be126-92c1-7721-a784-14d72b0eca79-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 8, 'total_tokens': 22, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# Len of Messages: 2
# Messages: {'messages': [HumanMessage(content='what is 2+2?', additional_kwargs={}, response_metadata={}, id='3bdd9ba8-801b-4cf0-b18c-88fa0dce456e'), AIMessage(content='2 + 2 equals 4.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 14, 'total_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UKX7tVbXHFxtVoyG1EdqbEOTJnP', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be126-92c1-7721-a784-14d72b0eca79-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 8, 'total_tokens': 22, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what is 10*5?', additional_kwargs={}, response_metadata={}, id='e9a286d1-a2b7-481d-99a5-7213d08d70d9'), AIMessage(content='10 * 5 equals 50.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 37, 'total_tokens': 45, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0UKZXpnZCckwBHbqKeERZx3WU4BU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be126-9ad3-7fa0-87fe-5a6c137b8f30-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 8, 'total_tokens': 45, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# Len of Messages: 4
# Messages: {'messages': [HumanMessage(content='what is 2+2?', additional_kwargs={}, response_metadata={}, id='3bdd9ba8-801b-4cf0-b18c-88fa0dce456e'), AIMessage(content='2 + 2 equals 4.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 14, 'total_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UKX7tVbXHFxtVoyG1EdqbEOTJnP', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be126-92c1-7721-a784-14d72b0eca79-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 8, 'total_tokens': 22, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what is 10*5?', additional_kwargs={}, response_metadata={}, id='e9a286d1-a2b7-481d-99a5-7213d08d70d9'), AIMessage(content='10 * 5 equals 50.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 37, 'total_tokens': 45, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0UKZXpnZCckwBHbqKeERZx3WU4BU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be126-9ad3-7fa0-87fe-5a6c137b8f30-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 8, 'total_tokens': 45, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what is 23*10?', additional_kwargs={}, response_metadata={}, id='31473e5e-5aef-4eeb-b297-32e8cd35a4f5'), AIMessage(content='23 * 10 equals 230.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 60, 'total_tokens': 68, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0UKaL8vRs2GeL5uL4pIjcUNWXDXD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be126-a0e9-7621-aacf-a7249c6160ee-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 60, 'output_tokens': 8, 'total_tokens': 68, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# Len of Messages: 6
# Messages: {'messages': [HumanMessage(content='what is 2+2?', additional_kwargs={}, response_metadata={}, id='3bdd9ba8-801b-4cf0-b18c-88fa0dce456e'), AIMessage(content='2 + 2 equals 4.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 14, 'total_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UKX7tVbXHFxtVoyG1EdqbEOTJnP', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be126-92c1-7721-a784-14d72b0eca79-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 8, 'total_tokens': 22, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what is 10*5?', additional_kwargs={}, response_metadata={}, id='e9a286d1-a2b7-481d-99a5-7213d08d70d9'), AIMessage(content='10 * 5 equals 50.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 37, 'total_tokens': 45, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0UKZXpnZCckwBHbqKeERZx3WU4BU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be126-9ad3-7fa0-87fe-5a6c137b8f30-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 8, 'total_tokens': 45, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what is 23*10?', additional_kwargs={}, response_metadata={}, id='31473e5e-5aef-4eeb-b297-32e8cd35a4f5'), AIMessage(content='23 * 10 equals 230.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 60, 'total_tokens': 68, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0UKaL8vRs2GeL5uL4pIjcUNWXDXD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be126-a0e9-7621-aacf-a7249c6160ee-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 60, 'output_tokens': 8, 'total_tokens': 68, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what is 18+11?', additional_kwargs={}, response_metadata={}, id='0ed475a1-8f63-4838-ad25-9e46616a9d06'), AIMessage(content='18 + 11 equals 29.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 83, 'total_tokens': 91, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0UKciOai9M1zsYHSEcpuye1on2Rq', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be126-a7d8-7f81-84d1-203fd60cc68e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 83, 'output_tokens': 8, 'total_tokens': 91, 'input_token_details': {'audio': 0, 'cac ...
# Len of Messages: 8
# Messages: {'messages': [HumanMessage(content='what is 2+2?', additional_kwargs={}, response_metadata={}, id='3bdd9ba8-801b-4cf0-b18c-88fa0dce456e'), AIMessage(content='2 + 2 equals 4.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 14, 'total_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UKX7tVbXHFxtVoyG1EdqbEOTJnP', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be126-92c1-7721-a784-14d72b0eca79-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 8, 'total_tokens': 22, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what is 10*5?', additional_kwargs={}, response_metadata={}, id='e9a286d1-a2b7-481d-99a5-7213d08d70d9'), AIMessage(content='10 * 5 equals 50.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 37, 'total_tokens': 45, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0UKZXpnZCckwBHbqKeERZx3WU4BU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be126-9ad3-7fa0-87fe-5a6c137b8f30-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 8, 'total_tokens': 45, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what is 23*10?', additional_kwargs={}, response_metadata={}, id='31473e5e-5aef-4eeb-b297-32e8cd35a4f5'), AIMessage(content='23 * 10 equals 230.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 60, 'total_tokens': 68, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0UKaL8vRs2GeL5uL4pIjcUNWXDXD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be126-a0e9-7621-aacf-a7249c6160ee-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 60, 'output_tokens': 8, 'total_tokens': 68, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what is 18+11?', additional_kwargs={}, response_metadata={}, id='0ed475a1-8f63-4838-ad25-9e46616a9d06'), AIMessage(content='18 + 11 equals 29.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 83, 'total_tokens': 91, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0UKciOai9M1zsYHSEcpuye1on2Rq', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be126-a7d8-7f81-84d1-203fd60cc68e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 83, 'output_tokens': 8, 'total_tokens': 91, 'input_token_details': {'audio': 0, 'cac ...
# Len of Messages: 10
# Messages: {'messages': [HumanMessage(content="Here is a summary of the conversation to date:\n\n## SESSION INTENT\nThe user's primary goal is to receive answers to basic mathematical questions.\n\n## SUMMARY\nThe user asked multiple arithmetic questions: \n1. What is 2 + 2? - Answer: 4\n2. What is 10 * 5? - Answer: 50\n3. What is 23 * 10? - Answer: 230\n\n## ARTIFACTS\nNone\n\n## NEXT STEPS\nContinue to answer the user's next arithmetic question regarding 18 + 11.", additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='dd2984a4-c205-4526-a266-9febe106d7f4'), AIMessage(content='18 + 11 equals 29.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 83, 'total_tokens': 91, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0UKciOai9M1zsYHSEcpuye1on2Rq', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be126-a7d8-7f81-84d1-203fd60cc68e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 83, 'output_tokens': 8, 'total_tokens': 91, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what is 22/7?', additional_kwargs={}, response_metadata={}, id='bb852d6f-6ccd-4a28-9d0e-6925260c1879'), AIMessage(content='22 divided by 7 equals approximately 3.142857, which is a common approximation for the mathematical constant π (pi).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 106, 'total_tokens': 132, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0UKdkveHTCTY3arx4E0aaR6Gkjsz', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be126-b036-7080-9580-3216abda1ad2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 106, 'output_tokens': 26, 'total_tokens': 132, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what is 100/4?', additional_kwargs={}, response_metadata={}, id='1ec999c3-5b4e-45dd-8727-117013a2d82d'), AIMessage(content='100 divided by 4 equals 25.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 186, 'total_tokens': 195, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UKkH8oqpEicVlspXQcOHkXpK335', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be126-c72c-7ec0-80df-f248b4cca597-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 186, 'output_tokens': 9, 'total_tokens': 195, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# Len of Messages: 6

# %% [markdown]
# #### Based on Token Size

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
from langgraph.checkpoint.memory import MemorySaver

@tool
def search_hotels(city: str) -> str:
    """ Search hotels in a city - returns long responses to use more tokens."""
    return f"""Hotels in {city}:
    1. Grand Hotel - 5 star, $350/night, spa, pool, gym
    2. City Inn - 4 star, $180/night, business center
    3. Budget Stay - 3 star, $75/night, free wifi"""

agent=create_agent(
    model="gpt-4o-mini",
    tools=[search_hotels],
    checkpointer=MemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model='gpt-4o-mini',
            trigger=("tokens", 550),
            keep=("tokens", 200)
        ),
    ]
)

config={"configurable": {"thread_id": "test-2"}}

# %%
# Token counter (approximate)
def count_tokens(messages):
    total_chars=sum(len(str(m.content)) for m in messages)
    return total_chars // 4

# %%
# Run test
cities = ["Paris", "London", "Tokyo", "New York", "Dubai", "Singapore"]

for city in cities:
    response = agent.invoke(
        {"messages": [HumanMessage(content=f"Find Hotels in {city}")]},
        config=config
    )

    tokens=count_tokens(response['messages'])
    print(f"{city} - {tokens} tokens, {len(response['messages'])} messages")
    print(f"{(response['messages'])}")
# Out:
# Paris - 144 tokens, 4 messages
# [HumanMessage(content='Find Hotels in Paris', additional_kwargs={}, response_metadata={}, id='9a9787ba-ed30-4a8a-bee5-7cd3d37b4ebf'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 56, 'total_tokens': 71, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UYkkv0iAVxLwdAoJNdW8YmTbW4A', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be134-07f0-73b0-97fd-b4b6f7aa9d99-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_3Q4ICjKVdDXsfgv70aWlG0Ej', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 56, 'output_tokens': 15, 'total_tokens': 71, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='05b57b45-b8cb-411d-8e25-2511eeb92b2b', tool_call_id='call_3Q4ICjKVdDXsfgv70aWlG0Ej'), AIMessage(content='Here are some hotel options in Paris:\n\n1. **Grand Hotel**\n   - Rating: 5 stars\n   - Price: $350/night\n   - Amenities: Spa, pool, gym\n\n2. **City Inn**\n   - Rating: 4 stars\n   - Price: $180/night\n   - Amenities: Business center\n\n3. **Budget Stay**\n   - Rating: 3 stars\n   - Price: $75/night\n   - Amenities: Free wifi\n\nLet me know if you need more information about any of these hotels!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 113, 'prompt_tokens': 140, 'total_tokens': 253, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UYmbAexL3ek6ACQ217tAfyAreBG', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be134-0dc2-72c1-9afe-c2be00165fd5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 140, 'output_tokens': 113, 'total_tokens': 253, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
# London - 287 tokens, 8 messages
# [HumanMessage(content='Find Hotels in Paris', additional_kwargs={}, response_metadata={}, id='9a9787ba-ed30-4a8a-bee5-7cd3d37b4ebf'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 56, 'total_tokens': 71, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UYkkv0iAVxLwdAoJNdW8YmTbW4A', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be134-07f0-73b0-97fd-b4b6f7aa9d99-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_3Q4ICjKVdDXsfgv70aWlG0Ej', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 56, 'output_tokens': 15, 'total_tokens': 71, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='05b57b45-b8cb-411d-8e25-2511eeb92b2b', tool_call_id='call_3Q4ICjKVdDXsfgv70aWlG0Ej'), AIMessage(content='Here are some hotel options in Paris:\n\n1. **Grand Hotel**\n   - Rating: 5 stars\n   - Price: $350/night\n   - Amenities: Spa, pool, gym\n\n2. **City Inn**\n   - Rating: 4 stars\n   - Price: $180/night\n   - Amenities: Business center\n\n3. **Budget Stay**\n   - Rating: 3 stars\n   - Price: $75/night\n   - Amenities: Free wifi\n\nLet me know if you need more information about any of these hotels!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 113, 'prompt_tokens': 140, 'total_tokens': 253, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UYmbAexL3ek6ACQ217tAfyAreBG', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be134-0dc2-72c1-9afe-c2be00165fd5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 140, 'output_tokens': 113, 'total_tokens': 253, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Find Hotels in London', additional_kwargs={}, response_metadata={}, id='8f7b03d8-236b-4f43-99dd-7fcb250c257f'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 264, 'total_tokens': 279, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UYs594l0W4FdtajL7QudDmQSqAZ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be134-23b5-7d62-859b-b479a3809ccb-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_WOqBqcDiVf889GuEQ9NDGBRN', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 264, 'output_tokens': 15, 'total_tokens': 279, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in London:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. B ...
# Tokyo - 433 tokens, 12 messages
# [HumanMessage(content='Find Hotels in Paris', additional_kwargs={}, response_metadata={}, id='9a9787ba-ed30-4a8a-bee5-7cd3d37b4ebf'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 56, 'total_tokens': 71, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UYkkv0iAVxLwdAoJNdW8YmTbW4A', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be134-07f0-73b0-97fd-b4b6f7aa9d99-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_3Q4ICjKVdDXsfgv70aWlG0Ej', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 56, 'output_tokens': 15, 'total_tokens': 71, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='05b57b45-b8cb-411d-8e25-2511eeb92b2b', tool_call_id='call_3Q4ICjKVdDXsfgv70aWlG0Ej'), AIMessage(content='Here are some hotel options in Paris:\n\n1. **Grand Hotel**\n   - Rating: 5 stars\n   - Price: $350/night\n   - Amenities: Spa, pool, gym\n\n2. **City Inn**\n   - Rating: 4 stars\n   - Price: $180/night\n   - Amenities: Business center\n\n3. **Budget Stay**\n   - Rating: 3 stars\n   - Price: $75/night\n   - Amenities: Free wifi\n\nLet me know if you need more information about any of these hotels!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 113, 'prompt_tokens': 140, 'total_tokens': 253, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UYmbAexL3ek6ACQ217tAfyAreBG', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be134-0dc2-72c1-9afe-c2be00165fd5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 140, 'output_tokens': 113, 'total_tokens': 253, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Find Hotels in London', additional_kwargs={}, response_metadata={}, id='8f7b03d8-236b-4f43-99dd-7fcb250c257f'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 264, 'total_tokens': 279, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UYs594l0W4FdtajL7QudDmQSqAZ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be134-23b5-7d62-859b-b479a3809ccb-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_WOqBqcDiVf889GuEQ9NDGBRN', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 264, 'output_tokens': 15, 'total_tokens': 279, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in London:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. B ...
# New York - 492 tokens, 8 messages
# [HumanMessage(content="Here is a summary of the conversation to date:\n\n## SESSION INTENT\nThe user's primary goal is to find hotel options in various cities, starting with Paris, London, and Tokyo.\n\n## SUMMARY\nThe user requested hotel information in Paris and London. The AI provided options that included the name, star rating, price per night, and amenities for each hotel. The hotels listed in both cities were the same:\n\n1. **Grand Hotel**\n   - Rating: 5 stars\n   - Price: $350/night\n   - Amenities: Spa, pool, gym\n\n2. **City Inn**\n   - Rating: 4 stars\n   - Price: $180/night\n   - Amenities: Business center\n\n3. **Budget Stay**\n   - Rating: 3 stars\n   - Price: $75/night\n   - Amenities: Free wifi\n\nThe user then requested hotel information for Tokyo.\n\n## ARTIFACTS\nNone\n\n## NEXT STEPS\nProvide hotel options in Tokyo.", additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='7d7aa9fa-bf74-4853-9b4a-c17e618f9135'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 469, 'total_tokens': 484, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UYyExTwOkDYFfuMvqpCDs9S2g3s', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be134-3d89-7583-94ad-23bfab534670-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Tokyo'}, 'id': 'call_h5EoJ5KMzfNBkqIhbxiYLCrx', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 469, 'output_tokens': 15, 'total_tokens': 484, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Tokyo:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='501906ae-f4d5-427d-8fea-55f1e6ffd295', tool_call_id='call_h5EoJ5KMzfNBkqIhbxiYLCrx'), AIMessage(content='Here are some hotel options in Tokyo:\n\n1. **Grand Hotel**\n   - Rating: 5 stars\n   - Price: $350/night\n   - Amenities: Spa, pool, gym\n\n2. **City Inn**\n   - Rating: 4 stars\n   - Price: $180/night\n   - Amenities: Business center\n\n3. **Budget Stay**\n   - Rating: 3 stars\n   - Price: $75/night\n   - Amenities: Free wifi\n\nIf you need more information or assistance with booking, just let me know!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 114, 'prompt_tokens': 553, 'total_tokens': 667, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UYzd6G4xTuwchYtrOTlRCucsaXK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be134-432a-7ef1-85d6-6e43fb2f27ed-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 553, 'output_tokens': 114, 'total_tokens': 667, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Find Hotels in New York', additional_kwargs={}, response_metadata={}, id='6109334c-923d-4783-9e2d-dbd1c4e47cea'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 462, 'total_tokens': 478, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'promp ...
# Dubai - 322 tokens, 5 messages
# [HumanMessage(content="Here is a summary of the conversation to date:\n\n## SESSION INTENT\nThe user's primary goal is to find hotel options in various cities, including Paris, London, Tokyo, and New York.\n\n## SUMMARY\nThe user requested hotel information in Paris, London, and Tokyo, receiving identical options for each city, which included:\n\n1. **Grand Hotel**\n   - Rating: 5 stars\n   - Price: $350/night\n   - Amenities: Spa, pool, gym\n\n2. **City Inn**\n   - Rating: 4 stars\n   - Price: $180/night\n   - Amenities: Business center\n\n3. **Budget Stay**\n   - Rating: 3 stars\n   - Price: $75/night\n   - Amenities: Free wifi\n\nThe user also requested hotel information for New York and received the same hotel options.\n\n## ARTIFACTS\nNone\n\n## NEXT STEPS\nNone", additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='94b9f121-bf44-4bae-abd6-e1e30cb9c66b'), HumanMessage(content='Find Hotels in Dubai', additional_kwargs={}, response_metadata={}, id='3921d14a-fe70-4931-9c4b-5c459cf6dcf1'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 578, 'total_tokens': 593, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UZNxrTQ4yXQWC2dVWaQu99fbfd2', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be134-a171-7d22-be0c-5a1d4b8bdf3b-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Dubai'}, 'id': 'call_HTOpYP6S4UzhJLZNR97T6VCU', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 578, 'output_tokens': 15, 'total_tokens': 593, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Dubai:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='b23ca014-75b4-4679-97aa-669ffb6709e7', tool_call_id='call_HTOpYP6S4UzhJLZNR97T6VCU'), AIMessage(content='Here are some hotel options in Dubai:\n\n1. **Grand Hotel**\n   - Rating: 5 stars\n   - Price: $350/night\n   - Amenities: Spa, pool, gym\n\n2. **City Inn**\n   - Rating: 4 stars\n   - Price: $180/night\n   - Amenities: Business center\n\n3. **Budget Stay**\n   - Rating: 3 stars\n   - Price: $75/night\n   - Amenities: Free wifi\n\nLet me know if you need more information or options!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 110, 'prompt_tokens': 329, 'total_tokens': 439, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UZUFGoOMDzET2BltXiqbaun2gp1', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be134-bd01-73a1-b9d7-fdb142dead81-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 329, 'output_tokens': 110, 'total_tokens': 439, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
# Singapore - 471 tokens, 9 messages
# [HumanMessage(content="Here is a summary of the conversation to date:\n\n## SESSION INTENT\nThe user's primary goal is to find hotel options in various cities, including Paris, London, Tokyo, and New York.\n\n## SUMMARY\nThe user requested hotel information in Paris, London, and Tokyo, receiving identical options for each city, which included:\n\n1. **Grand Hotel**\n   - Rating: 5 stars\n   - Price: $350/night\n   - Amenities: Spa, pool, gym\n\n2. **City Inn**\n   - Rating: 4 stars\n   - Price: $180/night\n   - Amenities: Business center\n\n3. **Budget Stay**\n   - Rating: 3 stars\n   - Price: $75/night\n   - Amenities: Free wifi\n\nThe user also requested hotel information for New York and received the same hotel options.\n\n## ARTIFACTS\nNone\n\n## NEXT STEPS\nNone", additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='94b9f121-bf44-4bae-abd6-e1e30cb9c66b'), HumanMessage(content='Find Hotels in Dubai', additional_kwargs={}, response_metadata={}, id='3921d14a-fe70-4931-9c4b-5c459cf6dcf1'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 578, 'total_tokens': 593, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UZNxrTQ4yXQWC2dVWaQu99fbfd2', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be134-a171-7d22-be0c-5a1d4b8bdf3b-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Dubai'}, 'id': 'call_HTOpYP6S4UzhJLZNR97T6VCU', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 578, 'output_tokens': 15, 'total_tokens': 593, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Dubai:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='b23ca014-75b4-4679-97aa-669ffb6709e7', tool_call_id='call_HTOpYP6S4UzhJLZNR97T6VCU'), AIMessage(content='Here are some hotel options in Dubai:\n\n1. **Grand Hotel**\n   - Rating: 5 stars\n   - Price: $350/night\n   - Amenities: Spa, pool, gym\n\n2. **City Inn**\n   - Rating: 4 stars\n   - Price: $180/night\n   - Amenities: Business center\n\n3. **Budget Stay**\n   - Rating: 3 stars\n   - Price: $75/night\n   - Amenities: Free wifi\n\nLet me know if you need more information or options!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 110, 'prompt_tokens': 329, 'total_tokens': 439, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0UZUFGoOMDzET2BltXiqbaun2gp1', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be134-bd01-73a1-b9d7-fdb142dead81-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 329, 'output_tokens': 110, 'total_tokens': 439, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Find Hotels in Singapore', additional_kwargs={}, response_metadata={}, id='75c06040-3b11-4cd1-bf7b-4534cf61f49e'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 450, 'total_tokens': 465, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, ...

# %% [markdown]
# ### Based on Fraction

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
from langgraph.checkpoint.memory import MemorySaver

@tool
def search_hotels(city: str) -> str:
    """ Search hotels for a given city """
    return f"Hotels in {city}: Grand Hotel $350, City Inn $180, Budget Stay $75"

# LOW Fraction for testing
agent=create_agent(
    model="gpt-4o-mini",
    tools=[search_hotels],
    checkpointer=MemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model="gpt-4o-mini",
            trigger=("fraction",0.005), # If the LLM is able to accomodate 160K tokens, 0.5% of 160K tokens is ~640 tokens
            keep=("fraction",0.002) # 0.2% is ~ 256 tokens
        ),
    ],
)
config={"configurable":{"thread_id":"test-3"}}

def count_tokens(messages):
    return sum(len(str(m.content)) for m in messages) // 4

# Test
cities = ["Paris", "London", "Tokyo", "New York", "Dubai", "Singapore","Bangalore"]

for city in cities:
    response=agent.invoke(
        {"messages": [HumanMessage(content=f"Hotels in {city}")]},
        config=config
    )
    tokens=count_tokens(response['messages'])
    fraction=tokens/128000 # gpt-4o-mini context
    print(f"{city}: ~{tokens} tokens ({fraction:.4%}), {len(response['messages'])} messages")
    print(f"{response['messages']}")
# Out:
# Paris: ~71 tokens (0.0555%), 4 messages
# [HumanMessage(content='Hotels in Paris', additional_kwargs={}, response_metadata={}, id='23f61891-7b1b-45f2-ad36-f9708a8c4be4'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 48, 'total_tokens': 63, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3BAoLmDGJxpmviDOHr1tmZBFYZ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be150-d431-7f21-8914-db6935ad09b1-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_SUjiN3nnsnlGIWEVDazgDh0F', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 48, 'output_tokens': 15, 'total_tokens': 63, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='32eb7006-7d73-453e-a34d-623c1958a3eb', tool_call_id='call_SUjiN3nnsnlGIWEVDazgDh0F'), AIMessage(content='Here are some hotels in Paris:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nLet me know if you need more information about any of these options!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 90, 'total_tokens': 148, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3Cv1IeroecxSS5dqFUUZPq5q1Y', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be150-d7ed-7f21-b97b-eaef0adb5509-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 90, 'output_tokens': 58, 'total_tokens': 148, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
# London: ~141 tokens (0.1102%), 8 messages
# [HumanMessage(content='Hotels in Paris', additional_kwargs={}, response_metadata={}, id='23f61891-7b1b-45f2-ad36-f9708a8c4be4'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 48, 'total_tokens': 63, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3BAoLmDGJxpmviDOHr1tmZBFYZ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be150-d431-7f21-8914-db6935ad09b1-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_SUjiN3nnsnlGIWEVDazgDh0F', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 48, 'output_tokens': 15, 'total_tokens': 63, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='32eb7006-7d73-453e-a34d-623c1958a3eb', tool_call_id='call_SUjiN3nnsnlGIWEVDazgDh0F'), AIMessage(content='Here are some hotels in Paris:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nLet me know if you need more information about any of these options!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 90, 'total_tokens': 148, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3Cv1IeroecxSS5dqFUUZPq5q1Y', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be150-d7ed-7f21-b97b-eaef0adb5509-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 90, 'output_tokens': 58, 'total_tokens': 148, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Hotels in London', additional_kwargs={}, response_metadata={}, id='7924c8f5-6cea-4db5-8912-719f015fd878'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 158, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3Gwt24upM9x5oRZr3M3uMbtGBc', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be150-e52c-7ab2-813f-44ddaa1ab7e8-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_vurif1XPkTMPaZ59VCkE65c9', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 158, 'output_tokens': 15, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in London: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='06351022-3dc7-4e8f-9ec9-93f21fe3be25', tool_call_id='call_vurif1XPkTMPaZ59VCkE65c9'), AIMessage(content='Here are some hotels in London:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nIf you need further details or assistance, feel free to ask!', additional_kwargs={'refusal': None}, response_met ...
# Tokyo: ~215 tokens (0.1680%), 12 messages
# [HumanMessage(content='Hotels in Paris', additional_kwargs={}, response_metadata={}, id='23f61891-7b1b-45f2-ad36-f9708a8c4be4'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 48, 'total_tokens': 63, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3BAoLmDGJxpmviDOHr1tmZBFYZ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be150-d431-7f21-8914-db6935ad09b1-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_SUjiN3nnsnlGIWEVDazgDh0F', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 48, 'output_tokens': 15, 'total_tokens': 63, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='32eb7006-7d73-453e-a34d-623c1958a3eb', tool_call_id='call_SUjiN3nnsnlGIWEVDazgDh0F'), AIMessage(content='Here are some hotels in Paris:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nLet me know if you need more information about any of these options!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 90, 'total_tokens': 148, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3Cv1IeroecxSS5dqFUUZPq5q1Y', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be150-d7ed-7f21-b97b-eaef0adb5509-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 90, 'output_tokens': 58, 'total_tokens': 148, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Hotels in London', additional_kwargs={}, response_metadata={}, id='7924c8f5-6cea-4db5-8912-719f015fd878'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 158, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3Gwt24upM9x5oRZr3M3uMbtGBc', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be150-e52c-7ab2-813f-44ddaa1ab7e8-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_vurif1XPkTMPaZ59VCkE65c9', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 158, 'output_tokens': 15, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in London: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='06351022-3dc7-4e8f-9ec9-93f21fe3be25', tool_call_id='call_vurif1XPkTMPaZ59VCkE65c9'), AIMessage(content='Here are some hotels in London:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nIf you need further details or assistance, feel free to ask!', additional_kwargs={'refusal': None}, response_met ...
# New York: ~288 tokens (0.2250%), 16 messages
# [HumanMessage(content='Hotels in Paris', additional_kwargs={}, response_metadata={}, id='23f61891-7b1b-45f2-ad36-f9708a8c4be4'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 48, 'total_tokens': 63, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3BAoLmDGJxpmviDOHr1tmZBFYZ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be150-d431-7f21-8914-db6935ad09b1-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_SUjiN3nnsnlGIWEVDazgDh0F', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 48, 'output_tokens': 15, 'total_tokens': 63, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='32eb7006-7d73-453e-a34d-623c1958a3eb', tool_call_id='call_SUjiN3nnsnlGIWEVDazgDh0F'), AIMessage(content='Here are some hotels in Paris:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nLet me know if you need more information about any of these options!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 90, 'total_tokens': 148, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3Cv1IeroecxSS5dqFUUZPq5q1Y', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be150-d7ed-7f21-b97b-eaef0adb5509-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 90, 'output_tokens': 58, 'total_tokens': 148, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Hotels in London', additional_kwargs={}, response_metadata={}, id='7924c8f5-6cea-4db5-8912-719f015fd878'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 158, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3Gwt24upM9x5oRZr3M3uMbtGBc', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be150-e52c-7ab2-813f-44ddaa1ab7e8-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_vurif1XPkTMPaZ59VCkE65c9', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 158, 'output_tokens': 15, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in London: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='06351022-3dc7-4e8f-9ec9-93f21fe3be25', tool_call_id='call_vurif1XPkTMPaZ59VCkE65c9'), AIMessage(content='Here are some hotels in London:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nIf you need further details or assistance, feel free to ask!', additional_kwargs={'refusal': None}, response_met ...
# Dubai: ~361 tokens (0.2820%), 20 messages
# [HumanMessage(content='Hotels in Paris', additional_kwargs={}, response_metadata={}, id='23f61891-7b1b-45f2-ad36-f9708a8c4be4'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 48, 'total_tokens': 63, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3BAoLmDGJxpmviDOHr1tmZBFYZ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be150-d431-7f21-8914-db6935ad09b1-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_SUjiN3nnsnlGIWEVDazgDh0F', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 48, 'output_tokens': 15, 'total_tokens': 63, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='32eb7006-7d73-453e-a34d-623c1958a3eb', tool_call_id='call_SUjiN3nnsnlGIWEVDazgDh0F'), AIMessage(content='Here are some hotels in Paris:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nLet me know if you need more information about any of these options!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 90, 'total_tokens': 148, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3Cv1IeroecxSS5dqFUUZPq5q1Y', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be150-d7ed-7f21-b97b-eaef0adb5509-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 90, 'output_tokens': 58, 'total_tokens': 148, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Hotels in London', additional_kwargs={}, response_metadata={}, id='7924c8f5-6cea-4db5-8912-719f015fd878'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 158, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3Gwt24upM9x5oRZr3M3uMbtGBc', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be150-e52c-7ab2-813f-44ddaa1ab7e8-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_vurif1XPkTMPaZ59VCkE65c9', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 158, 'output_tokens': 15, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in London: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='06351022-3dc7-4e8f-9ec9-93f21fe3be25', tool_call_id='call_vurif1XPkTMPaZ59VCkE65c9'), AIMessage(content='Here are some hotels in London:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nIf you need further details or assistance, feel free to ask!', additional_kwargs={'refusal': None}, response_met ...
# Singapore: ~416 tokens (0.3250%), 12 messages
# [HumanMessage(content="Here is a summary of the conversation to date:\n\n## SESSION INTENT\nThe user's primary goal is to find hotel options in various cities, specifically requesting information about hotels in Paris, London, Tokyo, and New York.\n\n## SUMMARY\nThe user inquired about hotel options in four different cities: Paris, London, Tokyo, and New York. For each request, the AI provided a list of hotels along with their nightly rates. The hotels listed in each city were the same:\n1. Grand Hotel - $350 per night\n2. City Inn - $180 per night\n3. Budget Stay - $75 per night\nThere were no rejected options; all queries were processed with standard hotel listings provided.\n\n## ARTIFACTS\nNone\n\n## NEXT STEPS\nThe user has requested hotels in New York. The next step is to retrieve and present hotel options in New York.", additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='04b58744-476f-477e-8320-963d4d09f024'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 379, 'total_tokens': 395, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3MAMf5tF3fm0hfN8kSvV6lBBkw', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be150-ff5a-7df0-aaaf-7c9d75e305bb-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'New York'}, 'id': 'call_hV9zhcMUw2MyqfQdfDRzspGU', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 379, 'output_tokens': 16, 'total_tokens': 395, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in New York: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='a750622f-00f5-4c6a-8006-6da9b6cee78b', tool_call_id='call_hV9zhcMUw2MyqfQdfDRzspGU'), AIMessage(content='Here are some hotels in New York:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nIf you have any questions or need more information, feel free to ask!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 423, 'total_tokens': 483, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3NpgwJ5mcxEhKWC6wtODdK5Tf0', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be151-03b5-7d52-8ba5-0ee39757e969-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 423, 'output_tokens': 60, 'total_tokens': 483, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Hotels in Dubai', additional_kwargs={}, response_metadata={}, id='c27e426a-e732-44a5-beff-39a5b87a2991'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 493, 'total_tokens': 508, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3QUl9xQeT3VYdfuNqjqLQB8Og4', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be151-0d8e-79d ...
# Bangalore: ~362 tokens (0.2828%), 9 messages
# [HumanMessage(content="Here is a summary of the conversation to date:\n\n## SESSION INTENT\nThe user's primary goal is to find hotel options in various cities, specifically requesting information about hotels in Paris, London, Tokyo, New York, and Dubai.\n\n## SUMMARY\nThe user inquired about hotel options in multiple cities: Paris, London, Tokyo, New York, and Dubai. For each request, the AI provided a list of hotels along with their nightly rates. The hotels listed in each city were the same:\n1. Grand Hotel - $350 per night\n2. City Inn - $180 per night\n3. Budget Stay - $75 per night. No options were rejected; all queries were processed with standard hotel listings provided.\n\n## ARTIFACTS\nNone\n\n## NEXT STEPS\nThe conversation has not outlined any specific remaining tasks aside from welcoming any further inquiries or requests for hotel information from the user.", additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='5469eff1-4ec3-4116-88a4-de425f6fd30d'), HumanMessage(content='Hotels in Singapore', additional_kwargs={}, response_metadata={}, id='273d5f60-81a6-4092-bb5d-aaee122ee49e'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 447, 'total_tokens': 462, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3aMUEoByGxxV25CfOYUDBmWGkE', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be151-33f6-7252-aa72-5e14272bb22d-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Singapore'}, 'id': 'call_YgjzeoEdIp0BScUG602wkGFk', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 447, 'output_tokens': 15, 'total_tokens': 462, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Singapore: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='4c27f19a-f4c3-4ea7-9e99-e1448a51cf14', tool_call_id='call_YgjzeoEdIp0BScUG602wkGFk'), AIMessage(content='Here are some hotels in Singapore:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nIf you need further assistance or additional options, just let me know!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 489, 'total_tokens': 547, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0V3btdZTvRlsDZNlLf5kf9CCILPZ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be151-37db-7081-b97c-0e394660a74d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 489, 'output_tokens': 58, 'total_tokens': 547, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Hotels in Bangalore', additional_kwargs={}, response_metadata={}, id='90ec8b29-9569-4d3a-b7c4-2c87206b679c'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 557, 'total_tokens': 573, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'syste ...

# %% [markdown]
# ## Human in the Loop
#
# Pause agent execution for human approval, editing, or rejection of tool calls before they execute. Human-in-the-loop is useful for the
# following:
# - High-stakes operations requiring human approval(e.g. database writes, finanacial transactions)
# - Compliance workflows where human oversight is mandatory
# - Long-running conversations where human feedback guides the agent

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langgraph.checkpoint.memory import MemorySaver

# %%
def read_email_tool(emailid: str) -> str:
    """ Mock function to read an email by its ID. """ 
    return f"Email content for ID: {emailid}"

def send_email_tool(recipient: str, subject: str, body:str) -> str:
    """ Mock function to send an email. """
    return f"Email sent to {recipient} with subject: {subject}"

# %%
agent=create_agent(
    model="gpt-4o",
    tools=[read_email_tool, send_email_tool],
    checkpointer=MemorySaver(),
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "send_email_tool": {
                    "allowed_decisions": ["approve", "edit", "reject"]
                },
                "read_email_tool": False,
            }
        )
    ]
)

# %%
config={"configurable": {"thread_id": "test_approve"}}

# Step 1: Request
result=agent.invoke(
    {"messages": [HumanMessage(content="Send email to ram@test.com with subject 'Hello' and body 'How are you?'")]},
    config=config
)
result
# Out:
# {'messages': [HumanMessage(content="Send email to ram@test.com with subject 'Hello' and body 'How are you?'", additional_kwargs={}, response_metadata={}, id='bf5c3875-c685-488a-ae2d-bcf9275ef380'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 97, 'total_tokens': 125, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-D0WOEJ0H9hIWrkWY3gGyFuhD4ouXP', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be19f-644a-7c01-bcf2-5a504634e207-0', tool_calls=[{'name': 'send_email_tool', 'args': {'recipient': 'ram@test.com', 'subject': 'Hello', 'body': 'How are you?'}, 'id': 'call_rm760mLKnT8nUTQP9b2fJjMd', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 97, 'output_tokens': 28, 'total_tokens': 125, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})],
#  '__interrupt__': [Interrupt(value={'action_requests': [{'name': 'send_email_tool', 'args': {'recipient': 'ram@test.com', 'subject': 'Hello', 'body': 'How are you?'}, 'description': "Tool execution requires approval\n\nTool: send_email_tool\nArgs: {'recipient': 'ram@test.com', 'subject': 'Hello', 'body': 'How are you?'}"}], 'review_configs': [{'action_name': 'send_email_tool', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='e8165a7a7118dd903d45c2a996ef4539')]}

# %%
# Step 2: Approve
from langgraph.types import Command
if "__interrupt__" in result:
    print("⏸️ Paused! Approving...")

    result=agent.invoke(
        Command(
            resume={
                "decisions": [
                    {"type": "approve"}
                ]
            }
        ),
        config=config
    )
    print(f"✅ Result: {result['messages'][-1].content}")
# Out:
# ⏸️ Paused! Approving...
# ✅ Result: The email has been sent to ram@test.com with the subject "Hello" and the body "How are you?".

# %%
result
# Out:
# {'messages': [HumanMessage(content="Send email to ram@test.com with subject 'Hello' and body 'How are you?'", additional_kwargs={}, response_metadata={}, id='bf5c3875-c685-488a-ae2d-bcf9275ef380'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 97, 'total_tokens': 125, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-D0WOEJ0H9hIWrkWY3gGyFuhD4ouXP', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be19f-644a-7c01-bcf2-5a504634e207-0', tool_calls=[{'name': 'send_email_tool', 'args': {'recipient': 'ram@test.com', 'subject': 'Hello', 'body': 'How are you?'}, 'id': 'call_rm760mLKnT8nUTQP9b2fJjMd', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 97, 'output_tokens': 28, 'total_tokens': 125, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='Email sent to ram@test.com with subject: Hello', name='send_email_tool', id='b05cd9e1-4f49-4d79-8ded-9fc6ec53c9fa', tool_call_id='call_rm760mLKnT8nUTQP9b2fJjMd'),
#   AIMessage(content='The email has been sent to ram@test.com with the subject "Hello" and the body "How are you?".', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 144, 'total_tokens': 168, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-D0WOI2Krta63P9QeEsEqd6AjqMGOV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be19f-722f-77e1-b19b-119a0291e7fe-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 144, 'output_tokens': 24, 'total_tokens': 168, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
# Step 2: Reject
config={"configurable": {"thread_id": "test_reject"}}

# Step 1: Request
result=agent.invoke(
    {"messages": [HumanMessage(content="Send email to ram@test.com with subject 'Hello' and body 'How are you?'")]},
    config=config
)
result

from langgraph.types import Command
if "__interrupt__" in result:
    print("⏸️ Paused! Rejecting...")

    result=agent.invoke(
        Command(
            resume={
                "decisions": [
                    {"type": "reject"}
                ]
            }
        ),
        config=config
    )
    print(f"❌ Result: {result['messages'][-1].content}")
# Out:
# ⏸️ Paused! Rejecting...
# ❌ Result: If there's anything specific you'd like to change or if you need help with something else, feel free to let me know!

# %%
result
# Out:
# {'messages': [HumanMessage(content="Send email to ram@test.com with subject 'Hello' and body 'How are you?'", additional_kwargs={}, response_metadata={}, id='68288fe1-c062-4f47-83b6-fcc9f357ea48'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 97, 'total_tokens': 125, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-D0WQR58EwtLOZrdoRkN2pcPoSkLZv', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be1a1-77ef-7ef2-9a62-f1a256285cd2-0', tool_calls=[{'name': 'send_email_tool', 'args': {'recipient': 'ram@test.com', 'subject': 'Hello', 'body': 'How are you?'}, 'id': 'call_BWvIlJQubcyo2O5UHdNzJpTF', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 97, 'output_tokens': 28, 'total_tokens': 125, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='User rejected the tool call for `send_email_tool` with id call_BWvIlJQubcyo2O5UHdNzJpTF', name='send_email_tool', id='7a094dc4-9d80-4040-b333-ec5acdebfc86', tool_call_id='call_BWvIlJQubcyo2O5UHdNzJpTF', status='error'),
#   AIMessage(content="If there's anything specific you'd like to change or if you need help with something else, feel free to let me know!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 166, 'total_tokens': 191, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-D0WQS5TDrAale1WVNnl0UMVKGlFcv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be1a1-80c6-7570-af65-dae06afe156a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 166, 'output_tokens': 25, 'total_tokens': 191, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
# Step 2: Reject
config={"configurable": {"thread_id": "test_edit"}}

# Step 1: Request
result=agent.invoke(
    {"messages": [HumanMessage(content="Send email to wrong@test.com with subject 'Hello' and body 'How are you?'")]},
    config=config
)
result

from langgraph.types import Command
if "__interrupt__" in result:
    print("⏸️ Paused! Editing...")

    result=agent.invoke(
        Command(
            resume={
                "decisions": [
                    {
                        "type": "edit",
                        "edited_action": 
                        {
                            "name": "send_email_tool",
                            "args": 
                            {
                                "recipient": "correct@email.com",
                                "subject": "Corrected Subject",
                                "body": "This email was edited by human before sending"
                            }
                        }
                     }
                ]
            }
        ),
        config=config
    )
    print(f"✍️ Result: {result['messages'][-1].content}")
# Out:
# ⏸️ Paused! Editing...
# ✍️ Result: The email has been sent with the corrected details.

# %%
result
# Out:
# {'messages': [HumanMessage(content="Send email to wrong@test.com with subject 'Hello' and body 'How are you?'", additional_kwargs={}, response_metadata={}, id='27d2e6e5-e65c-43c8-babf-96cc366f097b'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 97, 'total_tokens': 125, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-D0WV4BgxAsy6fIKagCqQAxFGVRlPx', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019be1a5-ded2-7320-acc8-3c415610e30b-0', tool_calls=[{'type': 'tool_call', 'name': 'send_email_tool', 'args': {'recipient': 'correct@email.com', 'subject': 'Corrected Subject', 'body': 'This email was edited by human before sending'}, 'id': 'call_SKpaLp3pOFbZOb3ZuHiZocNo'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 97, 'output_tokens': 28, 'total_tokens': 125, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='Email sent to correct@email.com with subject: Corrected Subject', name='send_email_tool', id='2af159f3-5aef-43d7-a1c5-75aa125ed5bf', tool_call_id='call_SKpaLp3pOFbZOb3ZuHiZocNo'),
#   AIMessage(content='The email has been sent with the corrected details.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 152, 'total_tokens': 163, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-D0WV6Lj9kI5kkVawJNtTqCiOFUI7d', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019be1a5-e49e-7540-9f5e-2ca8e36daaa7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 11, 'total_tokens': 163, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
